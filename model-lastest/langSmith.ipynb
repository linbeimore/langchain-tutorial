# %% [markdown]
# # LangSmith 使用
# > 全链路追踪,测评,监控

# %%
# 基础配置
import os
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
import dotenv
from rich import print as rprint

dotenv.load_dotenv(override=True)
# Out:
# True

# %%
# 创建 LLM 实例
llm = ChatOpenAI(
    model=os.getenv("MODEL_NAME"),
    openai_api_key=os.getenv("OPENAI_API_KEY"),
    openai_api_base=os.getenv("OPENAI_BASE_URL"),
)

# 直接调用，传入字符串
response = llm.invoke(input="什么是机器学习？")


rprint(response)
# Out:
# AIMessage(
#     content='机器学习是人工智能的一个核心分支，它的核心思想是让计算机系统能够**从数据中自动学习和改进**，而无需被显
# 式地、一步步地编程来执行特定任务。\n\n可以把它想象成教一个孩子认识世界的过程：\n\n-
# **传统编程**：你告诉计算机，“如果一只动物有四条腿、毛茸茸的、会喵喵叫，那么它就是猫。”\n-
# **机器学习**：你不给计算机具体的规则，而是给它**成千上万张猫和不是猫的图片**（数据），让它自己去寻找“猫”这个概念的
# 特征和规律。最终，它学到了一个能够识别猫的“模型”。当你给它一张全新的、从未见过的图片时，它也能判断里面是否有猫。\n\
# n### 机器学习的关键要素：\n1.  **数据**：这是“学习”的原材料。数据的质量和数量至关重要。\n2.
# **模型**：这是计算机用来做预测或决策的“数学函数”或“算法”。它从数据中学习，调整自身的内部参数。\n3.
# **训练**：将数据输入模型，通过优化算法（如梯度下降）不断调整模型参数，使其预测结果与真实答案的误差最小化。\n4.
# **预测/推断**：用训练好的模型对新的、未见过的数据进行预测或决策。\n\n### 常见的机器学习类型：\n-
# **监督学习**：模型从**带有标签**的数据中学习（例如，图片上标注了“猫”或“狗”）。学习目标是建立输入到输出的映射。这是
# 最常见的类型。\n-
# **无监督学习**：模型从**没有标签**的数据中学习，自行发现数据内在的结构、模式或关系（例如，将客户自动分成不同的群体
# ）。\n-
# **强化学习**：模型（智能体）通过与环境的互动来学习，根据获得的**奖励或惩罚信号**来调整自己的行为策略，以最大化长期
# 收益（例如，训练AI下棋、玩电子游戏）。\n\n### 生活中的机器学习应用：\n-
# **推荐系统**：购物网站推荐你可能喜欢的商品，视频平台推荐你可能感兴趣的视频。\n-
# **图像与语音识别**：手机人脸解锁、语音助手（如小爱同学）。\n- **自然语言处理**：机器翻译、智能客服、文本生成。\n-
# **金融科技**：信用评分、欺诈检测。\n-
# **自动驾驶**：环境感知、决策规划。\n\n总而言之，机器学习是一种让机器通过“经验”（数据）来提升特定任务性能的方法论，
# 它正深刻地改变着我们与技术互动的方式。',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 708,
#             'prompt_tokens': 251,
#             'total_tokens': 959,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 153,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 192}
#         },
#         'model_provider': 'openai',
#         'model_name': 'mimo-v2.5',
#         'system_fingerprint': None,
#         'id': 'c0bcce1957a749d69e976d717e405ab7',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f0e21-cbb3-78e2-8fa3-3dbe3bd2f80a-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 251,
#         'output_tokens': 708,
#         'total_tokens': 959,
#         'input_token_details': {'cache_read': 192},
#         'output_token_details': {'reasoning': 153}
#     }
# )
