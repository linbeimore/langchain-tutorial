# %% [markdown]
# # 消息与提示词

# %%
# 基础配置
import os
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import AIMessage, HumanMessage, ToolMessage, SystemMessage
import dotenv
from rich import print as rprint

dotenv.load_dotenv(override=True)
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv

load_dotenv()

# %%
# 创建 LLM 实例
llm = ChatOpenAI(
    model=os.getenv("MODEL_NAME"),
    openai_api_key=os.getenv("OPENAI_API_KEY"),
    openai_api_base=os.getenv("OPENAI_BASE_URL"),
)

# 直接调用，传入字符串
response = llm.invoke(input="你是谁?")


rprint(response)
# Out:
# AIMessage(
#     content='我是MiMo-v2.5，由小米大模型Core团队精心打造的人工智能助手~  (◕‿◕)
# 我拥有1M超长上下文处理能力，无论是知识问答、文本创作还是复杂推理，我都会尽力为你提供温暖又专业的陪伴！',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 144,
#             'prompt_tokens': 250,
#             'total_tokens': 394,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 81,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 192}
#         },
#         'model_provider': 'openai',
#         'model_name': 'mimo-v2.5',
#         'system_fingerprint': None,
#         'id': 'd403bf5558e74d978b823be6ae345dd9',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f0e31-486f-77a0-b1f6-cb015e90c95e-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 250,
#         'output_tokens': 144,
#         'total_tokens': 394,
#         'input_token_details': {'cache_read': 192},
#         'output_token_details': {'reasoning': 81}
#     }
# )

# %%
messages = [
  HumanMessage(content="我是一个粉刷家"),
  AIMessage(content="你好"),
  HumanMessage("请问我是谁?")
]

response = llm.invoke(messages)
rprint(response)
# Out:
# AIMessage(
#     content='根据你刚才告诉我的，你是一位**粉刷家**，也就是从事墙面粉刷、涂装工作的专业人士。\n\n请问你是专门做室内
# 墙面粉刷，还是也包括外墙涂装呢？',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 136,
#             'prompt_tokens': 267,
#             'total_tokens': 403,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 91,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256}
#         },
#         'model_provider': 'openai',
#         'model_name': 'mimo-v2.5',
#         'system_fingerprint': None,
#         'id': 'a24b130228774c0a89ba3f0701201793',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f0e3a-1494-7143-95cd-3571686199ab-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 267,
#         'output_tokens': 136,
#         'total_tokens': 403,
#         'input_token_details': {'cache_read': 256},
#         'output_token_details': {'reasoning': 91}
#     }
# )

# %% [markdown]
# ## 工具调用

# %% [markdown]
# ### 1. 定义工具

# %%
from langchain_core.tools import tool

@tool
def add(a: int, b: int) -> int:
    """将两个数字相加"""
    return a + b

@tool
def multiply(a: int, b: int) -> int:
    """将两个数字相乘"""
    return a * b

# 查看工具的 schema
print(add.name)
print(add.description)
print(add.args_schema.model_json_schema())
# Out:
# add
# 将两个数字相加
# {'description': '将两个数字相加', 'properties': {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}, 'required': ['a', 'b'], 'title': 'add', 'type': 'object'}

# %% [markdown]
# ### 2. 绑定工具并调用

# %%
# 将工具绑定到 LLM
llm_with_tools = llm.bind_tools([add, multiply])

# 发送消息，模型会决定是否调用工具
response = llm_with_tools.invoke("请计算 3 加 5 等于多少")

# 查看返回的 tool_calls
rprint(response)

# # 把拿到的tool_calls再次返回给llm
# tool_calls = response.tool_calls
# tool_message = ToolMessage(content=18,tool_call_id=tool_calls[0]['id'])
# messages = [HumanMessage("请计算 3 加 5 等于多少"), response,tool_message]
# final_message = llm_with_tools.invoke(messages)
# rprint(final_message)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 60,
#             'prompt_tokens': 599,
#             'total_tokens': 659,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 31,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 576}
#         },
#         'model_provider': 'openai',
#         'model_name': 'mimo-v2.5',
#         'system_fingerprint': None,
#         'id': '1b5e70fce95a46f386a23477e51be187',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019f0e76-f725-7581-827c-d9b795ac4ebf-0',
#     tool_calls=[
#         {'name': 'add', 'args': {'a': 3, 'b': 5}, 'id': 'call_92fba0f9dcdc46378582f9ac', 'type': 'tool_call'}
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 599,
#         'output_tokens': 60,
#         'total_tokens': 659,
#         'input_token_details': {'cache_read': 576},
#         'output_token_details': {'reasoning': 31}
#     }
# )

# %% [markdown]
# ### 3. 处理工具调用并获取最终结果

# %%
# 定义工具映射
tools_map = {"add": add, "multiply": multiply}

# 手动执行工具调用
if response.tool_calls:
    tool_call = response.tool_calls[0]  # 取第一个工具调用
    tool_name = tool_call["name"]
    tool_args = tool_call["args"]
    
    rprint(f"[bold]调用工具:[/bold] {tool_name}")
    rprint(f"[bold]参数:[/bold] {tool_args}")
    
    # 执行工具
    tool_result = tools_map[tool_name].invoke(tool_args)
    rprint(f"[bold]结果:[/bold] {tool_result}")
    
    # 构建完整对话历史
    messages = [
        HumanMessage("请计算 3 加 5 等于多少"),
        response,  # AIMessage (包含 tool_calls)
        ToolMessage(content=str(tool_result), tool_call_id=tool_call["id"]),
    ]
    
    # 再次调用 LLM 获取最终回答
    final_response = llm_with_tools.invoke(messages)
    rprint(f"\n[bold green]最终回答:[/bold green] {final_response.content}")
else:
    rprint("[yellow]模型未调用任何工具[/yellow]")
# Out:
# 调用工具: add
# 参数: {'a': 3, 'b': 5}
# 结果: 8
# 最终回答: 3 加 5 等于 **8**。
#
# 就像你手里有 3 个苹果，又拿来了 5 个苹果，现在一共有 8 个苹果啦！🍎
#
# 如果还有其他数字想计算，随时告诉我哦。

# %% [markdown]
# ### 4. 使用 `bind_tools` + 自动执行 (Tool Calling Agent)

# %%
from langchain_core.tools import tool

@tool
def get_weather(city: str) -> str:
    """查询指定城市的天气信息"""
    # 模拟天气数据
    weather_data = {
        "北京": "晴天，25°C",
        "上海": "多云，22°C",
        "广州": "小雨，28°C",
    }
    return weather_data.get(city, f"暂无 {city} 的天气数据")

@tool
def calculate(expression: str) -> str:
    """计算数学表达式"""
    try:
        result = eval(expression)
        return f"计算结果: {expression} = {result}"
    except Exception as e:
        return f"计算错误: {e}"

# 绑定工具
llm_with_tools = llm.bind_tools([get_weather, calculate])

# 测试天气查询
response = llm_with_tools.invoke("今天北京和上海的天气怎么样？")
rprint(response)

# %% [markdown]
# ### 5. 处理多个工具调用

# %%
# 处理多个工具调用
tools_map = {"get_weather": get_weather, "calculate": calculate}

if response.tool_calls:
    messages = [
        HumanMessage("今天北京和上海的天气怎么样？"),
        response,  # AIMessage (可能包含多个 tool_calls)
    ]
    
    # 执行所有工具调用
    for tc in response.tool_calls:
        tool_name = tc["name"]
        tool_args = tc["args"]
        
        rprint(f"[bold cyan]调用工具:[/bold cyan] {tool_name}({tool_args})")
        tool_result = tools_map[tool_name].invoke(tool_args)
        
        messages.append(ToolMessage(
            content=str(tool_result),
            tool_call_id=tc["id"],
        ))
        rprint(f"[bold green]结果:[/bold green] {tool_result}\n")
    
    # 获取最终回答
    final_response = llm_with_tools.invoke(messages)
    rprint(f"[bold yellow]最终回答:[/bold yellow] {final_response.content}")
else:
    rprint("[yellow]模型未调用任何工具[/yellow]")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # 处理多个工具调用
# ----> 2 tools_map = {"get_weather": get_weather, "calculate": calculate}
#       3
#       4 if response.tool_calls:
#       5     messages = [
#
# NameError: name 'get_weather' is not defined

# %% [markdown]
# > 由于llm是没有记忆的,就需要历史对话管理
# ## 对话管理
#  - 对话需要保存,需要维护消息列表
#  - 对话过长需要优化,减少不必要的token消耗
