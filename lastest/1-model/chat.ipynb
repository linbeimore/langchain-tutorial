# %% [markdown]
# # 模型调用
# ## chat类调用

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

llm = ChatOllama(model="qwen2.5:0.5b")

messages = [
    SystemMessage(content="你是一个Python编程助手，回答要简洁。"),
    HumanMessage(content="Python中如何读取JSON文件？"),
]

# response = llm.invoke(messages)
for chunk in llm.stream(messages):
    print(chunk.content,end="",flush=True)
# print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[1], line 12
#       8     HumanMessage(content="Python中如何读取JSON文件？"),
#       9 ]
#      10
#      11 # response = llm.invoke(messages)
# ---> 12 for chunk in llm.stream(messages):
#      13     print(chunk.content,end="",flush=True)
#      14 # print(response.content)
#
# File d:\hall\langchain-tutorial\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:776, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     774 index = -1
#     775 index_type = ""
# --> 776 for chunk in self._stream(input_messages, stop=stop, **kwargs):
#     777     if chunk.message.id is None:
#     778         chunk.message.id = run_id
#
# File d:\hall\langchain-tutorial\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1291, in ChatOllama._stream(self, messages, stop, run_manager, **kwargs)
#    1284 def _stream(
#    1285     self,
#    1286     messages: list[BaseMessage],
#    (...)   1289     **kwargs: Any,
#    1290 ) -> Iterator[ChatGenerationChunk]:
# -> 1291     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#    1292         if run_manager:
#    1293             run_manager.on_llm_new_token(
#    1294                 chunk.text,
#    1295                 verbose=self.verbose,
#    1296             )
#
# File d:\hall\langchain-tutorial\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1224, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1217 def _iterate_over_stream(
#    1218     self,
#    1219     messages: list[BaseMessage],
#    1220     stop: list[str] | None = None,
#    1221     **kwargs: Any,
#    1222 ) -> Iterator[ChatGenerationChunk]:
#    1223     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1224     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1225         if not isinstance(stream_resp, str):
#    1226             content = (
#    1227                 stream_resp["message"]["content"]
#    1228                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1229                 else ""
#    1230             )
#
# File d:\hall\langchain-tutorial\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1122, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#    1119 chat_params = self._chat_params(messages, stop, **kwargs)
#    1121 if chat_params["stream"]:
# -> 1122     yield from self._client.chat(**chat_params)
#    1123 else:
#    1124     yield self._client.chat(**chat_params)
#
# File d:\hall\langchain-tutorial\.venv\Lib\site-packages\ollama\_client.py:189, in Client._request.<locals>.inner()
#     187 except httpx.HTTPStatusError as e:
#     188   e.response.read()
# --> 189   raise ResponseError(e.response.text, e.response.status_code) from None
#     191 for line in r.iter_lines():
#     192   part = json.loads(line)
#
# ResponseError:  (status code: 502)

# %% [markdown]
# ## 使用init_chat_model初始化大模型实例
#
# ### stream 流式输出（阻塞式）

# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import SystemMessage, HumanMessage

llm = init_chat_model(model="qwen2.5:0.5b",model_provider="ollama")

messages = [
    SystemMessage(content="你是一个Python编程助手，回答要简洁。"),
    HumanMessage(content="Python中如何读取JSON文件？"),
]

for chunk in llm.stream(messages):
    print(chunk.content,end="",flush=True)

print("\nend")
# Out:
# 在Python中，你可以使用内置的`json`模块来读取和写入JSON文件。下面是一个简单的例子：
#
# ```python
# import json
#
# # 从一个包含数据的JSON文件中读取内容
# with open('data.json', 'r') as file:
#     data = json.load(file)
#
# # 将Python对象转换为JSON字符串
# json_data = json.dumps(data, indent=4)
# print(json_data)
# ```
#
# 在这个例子中，`open()`函数用于打开一个名为"data.json"的文件，并读取其中的内容。然后，我们使用`json.load()`函数将其转换为Python对象。最后，我们使用`json.dumps()`函数将Python对象转为JSON字符串。
#
# 请确保你已经安装了`json`模块。如果尚未安装，可以使用以下命令进行安装：
#
# ```sh
# pip install json
# ```
#
# 这将下载并安装`python-json-encode`库，该库包含`json`类，用于处理JSON数据和解析JSON格式的数据结构。end

# %% [markdown]
# ### astream (非阻塞式输出)

# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import SystemMessage, HumanMessage

llm = init_chat_model(model="qwen2.5:0.5b",model_provider="ollama")

messages = [
    SystemMessage(content="你是一个Python编程助手，回答要简洁。"),
    HumanMessage(content="Python中如何读取JSON文件？"),
]

async for chunk in llm.astream(messages):
    print(chunk.content,end="",flush=True)

print("\nend")
# Out:
# 在Python中，可以通过`json.load()`函数从JSON文件中加载数据。
#
# 例如，如果你有一个名为 `data.json` 的文件，你可以这样做：
#
# ```python
# with open('data.json', 'r') as file:
#     data = json.load(file)
# ```
#
# 这将读取并存储JSON数据到变量 `data` 中。
# end

# %% [markdown]
# ### invoke 阻塞模式调用

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

llm = ChatOllama(model="qwen2.5:0.5b")

messages = [
    SystemMessage(content="你是一个Python编程助手，回答要简洁。"),
    HumanMessage(content="Python中如何读取JSON文件？"),
]

response = llm.invoke(messages)
print(response.content)
# Out:
# 在Python中，可以通过内置的`json`模块来读取JSON文件。以下是一段示例代码：
#
# ```python
# import json
#
# with open('file.json', 'r') as f:
#     data = json.load(f)
# ```
#
# 这段代码打开名为'file.json'的JSON文件，并将其内容加载到变量`data`中。
#
# 如果你想在Python脚本内读取数据，可以在运行时调用这个函数：
#
# ```python
# import json
#
# data = {
#   "name": "John",
#   "age": 30,
#   "city": "New York"
# }
#
# with open('file.json', 'w') as f:
#     json.dump(data, f)
# ```
#
# 这段代码创建一个字典`data`，然后将其写入名为'file.json'的文件中。

# %% [markdown]
# ### ainvoke 非阻塞调用

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

llm = ChatOllama(model="qwen2.5:0.5b")

messages = [
    SystemMessage(content="你是一个Python编程助手，回答要简洁。"),
    HumanMessage(content="Python中如何读取JSON文件？"),
]

# ainvoke 是 invoke 的异步版本，需要用 await 调用
response = await llm.ainvoke(messages)
print(response.content)
# Out:
# 在Python中，你可以使用内置的json库来读取JSON文件。
#
# ```python
# import json
#
# with open('example.json', 'r') as f:
#     data = json.load(f)
# ```
#
# 这段代码首先打开名为'example.json'的文件，并将其读入一个名为"data"的对象。`json.load()`函数将Python解释器解析的JSON字符串加载到这个对象中。

# %% [markdown]
# ### batch 批量调用（同步）

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

llm = ChatOllama(model="qwen2.5:0.5b")

messages1 = [
    SystemMessage(content="你是一个Python编程助手，回答要简洁。"),
    HumanMessage(content="Python中如何读取JSON文件？"),
]

messages2 = [
    SystemMessage(content="你是一个Python编程助手，回答要简洁。"),
    HumanMessage(content="什么是列表推导式？"),
]

# batch 批量调用，同时处理多个请求
responses = llm.batch([messages1, messages2])

for i, response in enumerate(responses):
    print(f"\n--- 回复 {i+1} ---")
    print(response.content)
    print()
# Out:
# --- 回复 1 ---
# 在Python中，我们可以使用内置的json库来读取和解析JSON文件。以下是一个简单的示例：
#
# ```python
# import json
#
# def read_json_file(file_path):
#     with open(file_path, 'r') as file:
#         data = json.load(file)
#     return data
#
# file_path = 'example.json'
# data = read_json_file(file_path)
# print(data)
# ```
#
# 在这个例子中，我们首先导入了json库，然后定义了一个函数read_json_file。这个函数使用open()方法打开文件，并使用json.load()方法将文件内容转换为Python的字典类型的数据结构。
#
# 在主程序中，我们指定要读取的JSON文件的路径，然后调用read_json_file()函数并将其结果存储在data变量中。最后，我们打印出了数据。
#
# 注意：这个示例假设你的文件是按字典顺序保存的。如果你想要一个不同的排序方式（例如，根据属性排序），你可以通过修改json.load(file)中的序列化方式来实现。
#
#
# --- 回复 2 ---
# 在Python中，列表推导式是通过一个表达式的生成器生成一个新的列表。这种函数可以接收一个可迭代的对象，并返回一个新的列表，其中包含这些对象。
#
# 语法:
# ```python
# new_list = [expression for item in iterable]
# ```
#
# 例如：
#
# ```python
# [1, 2, 3]  # 只包含1, 2, 3
# [1, 2, 3, 4]  # 包含1, 2, 3, 4
# [1+2j, 3-4j]  # 可以包含任何支持列表推导的类型（如int、float和complex）
# ```
#
# 列表推导式可以用来快速生成大量数据，例如随机数、数学表达式等。

# %% [markdown]
# ### abatch 批量调用（异步）

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

llm = ChatOllama(model="qwen2.5:0.5b")

messages1 = [
    SystemMessage(content="你是一个Python编程助手，回答要简洁。"),
    HumanMessage(content="Python中如何读取JSON文件？"),
]

messages2 = [
    SystemMessage(content="你是一个Python编程助手，回答要简洁。"),
    HumanMessage(content="什么是列表推导式？"),
]

# abatch 是 batch 的异步版本，需要用 await 调用
responses = await llm.abatch([messages1, messages2])

for i, response in enumerate(responses):
    print(f"--- 回复 {i+1} ---")
    print(response.content)
    print()
# Out:
# --- 回复 1 ---
# 在Python中，可以使用内置的json库来读取JSON文件。以下是一个简单的示例：
#
# ```python
# import json
#
# # 读取JSON文件
# with open('file.json', 'r') as file:
#     data = json.load(file)
#
# print(data)
# ```
#
# 这段代码首先导入了json库，然后读取了一个名为'file.json'的JSON文件，并将其存储在一个变量中。最后，打印出这个变量的内容。
#
# 注意：在实际使用中，你需要将文件名替换为你想要加载的数据的实际路径或名称。
#
# --- 回复 2 ---
# 列表推导式的语法如下：
#
# ```python
# lst = [expression for item in iterable if condition]
# ```
#
# 其中：
# - `expression` 是迭代器的一个表达式。
# - `iterable` 是可迭代的序列，可以是任何可迭代对象（如字符串、整数等）。
# - `condition` 用来过滤哪些元素被包含在列表中。
#
# 例如：
#
# ```python
# lst = [x**2 for x in range(10)]
# print(lst) # 输出：[0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ```
#
# 在这个例子中，列表 `lst` 包含了从0到9的平方数。

# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import SystemMessage, HumanMessage

llm = init_chat_model(model="qwen2.5:0.5b",model_provider="ollama")

messages = [
    SystemMessage(content="你是一个Python编程助手，回答要简洁。"),
    HumanMessage(content="Python中如何读取JSON文件？"),
]

async for chunk in llm.astream(messages):
    print(chunk.content,end="",flush=True)

print("\nend")
# Out:
# 在Python中，可以使用`json`模块来读取JSON文件。
#
# ```python
# import json
#
# with open('file.json', 'r') as f:
#     data = json.load(f)
# ```
#
# 这段代码首先导入了`json`模块，然后创建了一个文件对象，并使用`open()`函数打开该文件。之后，通过`s.load()`方法加载数据到变量`data`中。
#
# 你可以根据需要修改你的JSON文件的路径或者内容。
# end
